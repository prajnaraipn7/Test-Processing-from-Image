# %%
import pytesseract

# %%
from PIL import Image

# %%
img=Image.open('error-an-unknown-directx-error-has-occurred-and-lol-cannot-start.jpg')

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=535x229 at 0x20726D9B780>

# %%
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files (x86)/Tesseract-OCR/tesseract'

# %%
result1=pytesseract.image_to_string(img)
print(result1)
# Out:
# An unknown Dneax error has uimrred and League of Legends cannot
# start Please make sure yuurvldeu card Is using the latest video drivers
# from the manufacturer.
#
# L

# %%
with open('error.txt',mode ='w') as file:
    file.write(result1)

# %%
with ope(n)
